# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import numpy as np
import matplotlib as plt
import k3d
import trimesh
import torch
import skimage
import torchvision

import PIL
print('Pillow Version:', PIL.__version__)
torch.cuda.is_available()
# Out:
# Pillow Version: 7.2.0
# True

# %%
from mvcnn_rec.data.shapenet import ShapeNetMultiview
from mvcnn_rec.model.mvcnn_rec import MVCNNReconstruction
from mvcnn_rec.training import validation

# %% [markdown]
# ### Evalutation by class

# %%
config = {
    'device': 'cuda:0',  # change this to cpu if you do not have a GPU
    'is_overfit': False,
    'batch_size': 16,
    'resume_ckpt': 'mvcnn_rec/runs/model_best_1views.ckpt',
    'num_views': 1, # Num views from total 24 views (stride = 24 / num_views)
    'dataset': 'test', # Change to test to validation on test set
    'print_every_n': 50,
    'num_workers': 8,
    'validation_mode': 'class',
}
validation.main(config)
# Out:
# Using device: cuda:0
# 2022-01-31 21:36:42.109489 Start validating!
# Class aeroplane: accuracy: 100.000%.
# Class car: accuracy: 0.000%.
# Class chair: accuracy: 0.000%.
# Class display: accuracy: 0.000%.
# Class rifle: accuracy: 0.000%.
# Class table: accuracy: 0.000%.
# Class watercraft: accuracy: 0.000%.
# 2022-01-31 21:36:43.889500 Batch id 49: val_accuracy: 97.500%, val_IoU: 0.4779489040374756.
# Class aeroplane: accuracy: 99.747%.
# Class bench: accuracy: 98.947%.
# Class cabinet: accuracy: 99.180%.
# Class car: accuracy: 97.368%.
# Class chair: accuracy: 0.000%.
# Class display: accuracy: 0.000%.
# Class speaker: accuracy: 0.000%.
# Class rifle: accuracy: 0.000%.
# Class sofa: accuracy: 0.000%.
# Class table: accuracy: 0.000%.
# Class telephone: accuracy: 0.000%.
# Class watercraft: accuracy: 0.000%.
# 2022-01-31 21:36:44.929329 Batch id 99: val_accuracy: 89.062%, val_IoU: 0.5189208388328552.
# Class aeroplane: accuracy: 99.747%.
# Class bench: accuracy: 98.947%.
# ...

# %%
config = {
    'device': 'cuda:0',  # change this to cpu if you do not have a GPU
    'is_overfit': False,
    'batch_size': 16,
    'resume_ckpt': 'mvcnn_rec/runs/model_best_3views.ckpt',
    'num_views': 3, # Num views from total 24 views (stride = 24 / num_views)
    'dataset': 'test', # Change to test to validation on test set
    'print_every_n': 50,
    'num_workers': 8,
    'validation_mode': 'class',
}
validation.main(config)
# Out:
# Using device: cuda:0
# 2022-01-31 21:38:21.025173 Start validating!
# Class aeroplane: accuracy: 100.000%.
# Class lamp: accuracy: 0.000%.
# Class rifle: accuracy: 0.000%.
# Class watercraft: accuracy: 0.000%.
# 2022-01-31 21:38:24.597042 Batch id 49: val_accuracy: 98.500%, val_IoU: 0.49568498134613037.
# Class aeroplane: accuracy: 99.875%.
# Class bench: accuracy: 99.660%.
# Class cabinet: accuracy: 99.322%.
# Class car: accuracy: 100.000%.
# Class chair: accuracy: 0.000%.
# Class lamp: accuracy: 0.000%.
# Class speaker: accuracy: 0.000%.
# Class rifle: accuracy: 0.000%.
# Class sofa: accuracy: 0.000%.
# Class table: accuracy: 0.000%.
# Class telephone: accuracy: 0.000%.
# Class watercraft: accuracy: 0.000%.
# 2022-01-31 21:38:27.358412 Batch id 99: val_accuracy: 93.375%, val_IoU: 0.5541667938232422.
# Class aeroplane: accuracy: 99.875%.
# Class bench: accuracy: 99.660%.
# Class cabinet: accuracy: 99.322%.
# Class car: accuracy: 100.000%.
# Class chair: accuracy: 0.000%.
# ...

# %%
config = {
    'device': 'cuda:0',  # change this to cpu if you do not have a GPU
    'is_overfit': False,
    'batch_size': 16,
    'resume_ckpt': 'mvcnn_rec/runs/model_best_12views.ckpt',
    'num_views': 12, # Num views from total 24 views (stride = 24 / num_views)
    'dataset': 'test', # Change to test to validation on test set
    'print_every_n': 50,
    'num_workers': 8,
    'validation_mode': 'class',
}
validation.main(config)
# Out:
# Using device: cuda:0
# 2022-01-31 21:43:51.752844 Start validating!
# Class aeroplane: accuracy: 100.000%.
# Class lamp: accuracy: 0.000%.
# Class rifle: accuracy: 0.000%.
# Class watercraft: accuracy: 0.000%.
# 2022-01-31 21:44:06.021543 Batch id 49: val_accuracy: 99.000%, val_IoU: 0.5568576455116272.
# Class aeroplane: accuracy: 99.875%.
# Class bench: accuracy: 100.000%.
# Class cabinet: accuracy: 98.955%.
# Class car: accuracy: 100.000%.
# Class chair: accuracy: 0.000%.
# Class display: accuracy: 0.000%.
# Class lamp: accuracy: 0.000%.
# Class speaker: accuracy: 0.000%.
# Class rifle: accuracy: 0.000%.
# Class sofa: accuracy: 0.000%.
# Class table: accuracy: 0.000%.
# Class telephone: accuracy: 0.000%.
# Class watercraft: accuracy: 0.000%.
# 2022-01-31 21:44:16.669305 Batch id 99: val_accuracy: 91.375%, val_IoU: 0.6117129921913147.
# Class aeroplane: accuracy: 99.627%.
# Class bench: accuracy: 100.000%.
# Class cabinet: accuracy: 98.955%.
# Class car: accuracy: 100.000%.
# ...

# %% [markdown]
# ### IoU

# %%
config = {
    'device': 'cuda:0',  # change this to cpu if you do not have a GPU
    'is_overfit': False,
    'batch_size': 16,
    'resume_ckpt': 'mvcnn_rec/runs/model_best_1views.ckpt',
    'num_views': 1, # Num views from total 24 views (stride = 24 / num_views)
    'dataset': 'test', # Change to test to validation on test set
    'print_every_n': 100,
    'num_workers': 8,
    'validation_mode': 'class',
}
validation.main(config)
# Out:
# Using device: cuda:0
# 2022-01-31 22:42:43.684799 Start validating!
#
# Accuracy by class:
# aeroplane: 99.747%.
# bench: 98.947%.
# cabinet: 99.180%.
# car: 97.368%.
# chair: 0.000%.
# display: 0.000%.
# speaker: 0.000%.
# rifle: 0.000%.
# sofa: 0.000%.
# table: 0.000%.
# telephone: 0.000%.
# watercraft: 0.000%.
#
# Mean IoU by class:
# aeroplane: 0.478.
# bench: 0.388.
# cabinet: 0.677.
# car: 0.780.
# 2022-01-31 22:42:46.467426 Batch id 99: val_accuracy: 89.062%, val_IoU: 0.5189208984375.
#
# Accuracy by class:
# aeroplane: 99.622%.
# bench: 98.258%.
# cabinet: 99.180%.
# car: 99.799%.
# chair: 92.019%.
# display: 0.000%.
# lamp: 0.000%.
# speaker: 0.000%.
# rifle: 0.000%.
# sofa: 0.000%.
# table: 0.000%.
# telephone: 0.000%.
# watercraft: 0.000%.
#
# Mean IoU by class:
# aeroplane: 0.478.
# bench: 0.388.
# cabinet: 0.677.
# car: 0.778.
# chair: 0.499.
# 2022-01-31 22:42:48.613752 Batch id 199: val_accuracy: 93.812%, val_IoU: 0.6302627921104431.
#
# Accuracy by class:
# ...

# %%
config = {
    'device': 'cuda:0',  # change this to cpu if you do not have a GPU
    'is_overfit': False,
    'batch_size': 16,
    'resume_ckpt': 'mvcnn_rec/runs/model_best_3views.ckpt',
    'num_views': 3, # Num views from total 24 views (stride = 24 / num_views)
    'dataset': 'test', # Change to test to validation on test set
    'print_every_n': 100,
    'num_workers': 8,
    'validation_mode': 'class',
}
validation.main(config)
# Out:
# Using device: cuda:0
# 2022-01-31 22:42:56.651423 Start validating!
#
# Accuracy by class:
# aeroplane: 99.875%.
# bench: 99.660%.
# cabinet: 99.322%.
# car: 100.000%.
# chair: 0.000%.
# lamp: 0.000%.
# speaker: 0.000%.
# rifle: 0.000%.
# sofa: 0.000%.
# table: 0.000%.
# telephone: 0.000%.
# watercraft: 0.000%.
#
# Mean IoU by class:
# aeroplane: 0.495.
# bench: 0.465.
# cabinet: 0.718.
# car: 0.795.
# 2022-01-31 22:43:02.927394 Batch id 99: val_accuracy: 93.375%, val_IoU: 0.5541667938232422.
#
# Accuracy by class:
# aeroplane: 99.875%.
# bench: 98.653%.
# cabinet: 99.322%.
# car: 100.000%.
# chair: 89.732%.
# lamp: 0.000%.
# speaker: 0.000%.
# rifle: 0.000%.
# sofa: 0.000%.
# table: 0.000%.
# telephone: 0.000%.
# watercraft: 0.000%.
#
# Mean IoU by class:
# aeroplane: 0.495.
# bench: 0.465.
# cabinet: 0.718.
# car: 0.806.
# chair: 0.558.
# 2022-01-31 22:43:08.549914 Batch id 199: val_accuracy: 96.281%, val_IoU: 0.6641942262649536.
#
# Accuracy by class:
# aeroplane: 99.750%.
# ...

# %%
config = {
    'device': 'cuda:0',  # change this to cpu if you do not have a GPU
    'is_overfit': False,
    'batch_size': 16,
    'resume_ckpt': 'mvcnn_rec/runs/model_best_12views.ckpt',
    'num_views': 12, # Num views from total 24 views (stride = 24 / num_views)
    'dataset': 'test', # Change to test to validation on test set
    'print_every_n': 100,
    'num_workers': 8,
    'validation_mode': 'class',
}
validation.main(config)
# Out:
# Using device: cuda:0
# 2022-01-31 22:43:28.757148 Start validating!
#
# Accuracy by class:
# aeroplane: 99.875%.
# bench: 100.000%.
# cabinet: 98.955%.
# car: 100.000%.
# chair: 0.000%.
# display: 0.000%.
# lamp: 0.000%.
# speaker: 0.000%.
# rifle: 0.000%.
# sofa: 0.000%.
# table: 0.000%.
# telephone: 0.000%.
# watercraft: 0.000%.
#
# Mean IoU by class:
# aeroplane: 0.556.
# bench: 0.528.
# cabinet: 0.769.
# car: 0.825.
# 2022-01-31 22:43:51.085673 Batch id 99: val_accuracy: 91.375%, val_IoU: 0.6117129921913147.
#
# Accuracy by class:
# aeroplane: 99.504%.
# bench: 99.251%.
# cabinet: 98.955%.
# car: 100.000%.
# chair: 88.938%.
# display: 0.000%.
# lamp: 0.000%.
# speaker: 0.000%.
# rifle: 0.000%.
# sofa: 0.000%.
# table: 0.000%.
# telephone: 0.000%.
# watercraft: 0.000%.
#
# Mean IoU by class:
# aeroplane: 0.556.
# bench: 0.528.
# cabinet: 0.769.
# car: 0.829.
# chair: 0.605.
# 2022-01-31 22:44:12.362282 Batch id 199: val_accuracy: 95.250%, val_IoU: 0.7059910297393799.
#
# ...
